# %% [markdown]
# # Week 2: Python Fundamentals for Historians
#
# **Name:** [Your Name]
# **Date:** [Date]
#
# ## Instructions
#
# Complete each exercise below. Add markdown cells to explain your approach and reasoning. Test your code to ensure it runs without errors.
#
# **AI Use Policy:** You may use GitHub Copilot for this assignment, but you MUST document your AI usage in the `AI-use-log.md` file.

# %% [markdown]
# ## Exercise 1: Variables and Data Types
#
# Create variables to store information about a historical figure. Include:
# - A string for their name
# - An integer for their birth year
# - A float for a historical event year (can include decimal for month approximation)
# - A boolean for whether they are still alive
# - A list of their major accomplishments (at least 3 items)
#
# Print each variable with a descriptive label.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: String Manipulation
#
# Given the following string containing a historical document excerpt:
#
# ```python
# document = "We hold these truths to be self-evident, that all men are created equal."
# ```
#
# Perform the following operations:
# 1. Convert the string to uppercase
# 2. Count how many times the letter 'e' appears
# 3. Replace "men" with "people"
# 4. Split the string into a list of words
# 5. Print the length of the document in characters

# %%
document = "We hold these truths to be self-evident, that all men are created equal."

# Your code here

# %% [markdown]
# ## Exercise 3: Lists and Indexing
#
# You have a list of U.S. presidents in chronological order:
#
# ```python
# presidents = ["Washington", "Adams", "Jefferson", "Madison", "Monroe", "Adams", "Jackson"]
# ```
#
# Write code to:
# 1. Print the first president
# 2. Print the last president
# 3. Print the 3rd through 5th presidents (slice)
# 4. Add "Van Buren" to the end of the list
# 5. Insert "Tyler" at position 10 (you'll need to add a few more presidents first)
# 6. Print the total number of presidents in the list

# %%
presidents = ["Washington", "Adams", "Jefferson", "Madison", "Monroe", "Adams", "Jackson"]

# Your code here

# %% [markdown]
# ## Exercise 4: Dictionaries
#
# Create a dictionary to store information about a historical event. Include at least:
# - Event name
# - Date
# - Location
# - Key figures (as a list)
# - Significance (short description)
#
# Then:
# 1. Print the entire dictionary
# 2. Access and print just the event name
# 3. Add a new key-value pair for "sources" (a list of at least 2 sources)
# 4. Update the significance with additional information
# 5. Print all the dictionary keys
# 6. Print all the dictionary values

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Control Flow - If/Else Statements
#
# Write a program that takes a year as input and determines which historical period it belongs to:
#
# - Before 1492: "Pre-Columbian Era"
# - 1492-1776: "Colonial Period"
# - 1776-1865: "Early Republic and Civil War"
# - 1865-1945: "Industrial Age and World Wars"
# - 1945-1991: "Cold War Era"
# - 1991-present: "Contemporary Period"
#
# Test your code with at least 3 different years.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: For Loops
#
# You have a list of historical dates (as years). Write a loop to:
# 1. Print each year
# 2. Determine if it's a leap year (divisible by 4, except centuries unless divisible by 400)
# 3. Count how many leap years are in your list
#
# Test with this list:
# ```python
# years = [1776, 1800, 1865, 1900, 1945, 2000, 2020]
# ```

# %%
years = [1776, 1800, 1865, 1900, 1945, 2000, 2020]

# Your code here

# %% [markdown]
# ## Exercise 7: Functions
#
# Write a function called `calculate_age()` that:
# - Takes two parameters: birth_year and current_year
# - Returns the age
# - Includes a docstring explaining what the function does
#
# Then write another function called `historical_age()` that:
# - Takes three parameters: birth_year, death_year, and name
# - Calculates the person's age at death
# - Returns a formatted string like: "Abraham Lincoln lived to be 56 years old."
#
# Test both functions with historical figures.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Working with Real Historical Data
#
# You have a list of dictionaries representing historical battles:
#
# ```python
# battles = [
#     {"name": "Gettysburg", "year": 1863, "casualties": 51000},
#     {"name": "Antietam", "year": 1862, "casualties": 22717},
#     {"name": "Chancellorsville", "year": 1863, "casualties": 30000},
#     {"name": "Shiloh", "year": 1862, "casualties": 23746}
# ]
# ```
#
# Write code to:
# 1. Print the name of each battle
# 2. Find the battle with the most casualties
# 3. Calculate the total casualties across all battles
# 4. Find all battles that occurred in 1863
# 5. Sort the battles by year (you may need to research how to do this!)

# %%
battles = [
    {"name": "Gettysburg", "year": 1863, "casualties": 51000},
    {"name": "Antietam", "year": 1862, "casualties": 22717},
    {"name": "Chancellorsville", "year": 1863, "casualties": 30000},
    {"name": "Shiloh", "year": 1862, "casualties": 23746}
]

# Your code here

# %% [markdown]
# ## Exercise 9: File I/O (Basic)
#
# Write code to:
# 1. Create a list of at least 5 historical events (just strings)
# 2. Write this list to a text file called `events.txt`, with one event per line
# 3. Read the file back in and print each line
# 4. Append a new event to the file
#
# **Note:** The Programming Historian tutorial (Part 2 of this week's assignment) will give you more practice with file I/O!

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Challenge - Text Analysis
#
# Given this excerpt from the Gettysburg Address:
#
# ```python
# gettysburg = """Four score and seven years ago our fathers brought forth on this continent,
# a new nation, conceived in Liberty, and dedicated to the proposition that all men are created equal.
# Now we are engaged in a great civil war, testing whether that nation, or any nation so conceived
# and so dedicated, can long endure."""
# ```
#
# Write code to:
# 1. Count the total number of words
# 2. Find the most common word (excluding "and", "the", "a", "in", "to", "that")
# 3. Count how many times "nation" appears
# 4. Create a list of all unique words (convert to lowercase first)
# 5. Calculate the average word length
#
# **Hint:** You'll need to use string methods, lists, and loops. This is a challenging exercise that combines multiple concepts!

# %%
gettysburg = """Four score and seven years ago our fathers brought forth on this continent, 
a new nation, conceived in Liberty, and dedicated to the proposition that all men are created equal.
Now we are engaged in a great civil war, testing whether that nation, or any nation so conceived 
and so dedicated, can long endure."""

# Your code here

# %% [markdown]
# ## Reflection
#
# In the markdown cell below, write a brief reflection (3-5 sentences) about:
# - Which exercises were most challenging?
# - How might these Python skills be useful for historical research?
# - What questions do you still have about Python?

# %% [markdown]
# **Your reflection here:**

# %% [markdown]
# ## Submission
#
# Before submitting:
# 1. Run all cells to ensure there are no errors
# 2. Complete the `AI-use-log.md` file
# 3. Complete the Programming Historian tutorial in `../ph-text-files/`
# 4. Commit and push all your work to GitHub
#
# **Due:** Monday, February 2 at 9:00 AM
